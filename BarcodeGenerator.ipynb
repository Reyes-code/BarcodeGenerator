# %%
import barcode
import pandas as pd
from barcode.writer import ImageWriter

# %%
data =pd.read_excel("codigosbarrra.xlsx")
data
# Out:
#        Código
# 0    LBB00001
# 1    LBB00002
# 2    LBB00003
# 3    LBB00004
# 4    LBB00005
# ..        ...
# 103  LBB00104
# 104  LBB00105
# 105  LBB00106
# 106  LBB00107
# 107  LBB00108
#
# [108 rows x 1 columns]

# %%
def generar_codigo_de_barras(numero, formato):
    # Crea un objeto de código de barras EAN-128
    codigo_de_barras = barcode.get(formato, numero, writer=ImageWriter())

    # Guarda el código de barras en un archivo
    nombre_archivo = f"{numero}"
    codigo_de_barras.save(nombre_archivo)

    print(f"Se generó el código de barras en el archivo: {nombre_archivo}")

# %%
for i in data["Código"]:
    numero_codigo = i
    formato_codigo = "code128"
    generar_codigo_de_barras(numero_codigo, formato_codigo)
# Out:
# Se generó el código de barras en el archivo: LBB00001
# Se generó el código de barras en el archivo: LBB00002
# Se generó el código de barras en el archivo: LBB00003
# Se generó el código de barras en el archivo: LBB00004
# Se generó el código de barras en el archivo: LBB00005
# Se generó el código de barras en el archivo: LBB00006
# Se generó el código de barras en el archivo: LBB00007
# Se generó el código de barras en el archivo: LBB00008
# Se generó el código de barras en el archivo: LBB00009
# Se generó el código de barras en el archivo: LBB00010
# Se generó el código de barras en el archivo: LBB00011
# Se generó el código de barras en el archivo: LBB00012
# Se generó el código de barras en el archivo: LBB00013
# Se generó el código de barras en el archivo: LBB00014
# Se generó el código de barras en el archivo: LBB00015
# Se generó el código de barras en el archivo: LBB00016
# Se generó el código de barras en el archivo: LBB00017
# Se generó el código de barras en el archivo: LBB00018
# Se generó el código de barras en el archivo: LBB00019
# Se generó el código de barras en el archivo: LBB00020
# Se generó el código de barras en el archivo: LBB00021
# Se generó el código de barras en el archivo: LBB00022
# Se generó el código de barras en el archivo: LBB00023
# Se generó el código de barras en el archivo: LBB00024
# Se generó el código de barras en el archivo: LBB00025
# Se generó el código de barras en el archivo: LBB00026
# Se generó el código de barras en el archivo: LBB00027
# Se generó el código de barras en el archivo: LBB00028
# Se generó el código de barras en el archivo: LBB00029
# Se generó el código de barras en el archivo: LBB00030
# Se generó el código de barras en el archivo: LBB00031
# Se generó el código de barras en el archivo: LBB00032
# Se generó el código de barras en el archivo: LBB00033
# Se generó el código de barras en el archivo: LBB00034
# Se generó el código de barras en el archivo: LBB00035
# Se generó el código de barras en el archivo: LBB00036
# Se generó el código de barras en el archivo: LBB00037
# Se generó el código de barras en el archivo: LBB00038
# Se generó el código de barras en el archivo: LBB00039
# Se generó el código de barras en el archivo: LBB00040
# Se generó el código de barras en el archivo: LBB00041
# Se generó el código de barras en el archivo: LBB00042
# Se generó el código de barras en el archivo: LBB00043
# Se generó el código de barras en el archivo: LBB00044
# Se generó el código de barras en el archivo: LBB00045
# Se generó el código de barras en el archivo: LBB00046
# Se generó el código de barras en el archivo: LBB00047
# Se generó el código de barras en el archivo: LBB00048
# Se generó el código de barras en el archivo: LBB00049
# Se generó el código de barras en el archivo: LBB00050
# Se generó el código de barras en el archivo: LBB00051
# Se generó el código de barras en el archivo: LBB00052
# Se generó el código de barras en el archivo: LBB00053
# Se generó el código de barras en el archivo: LBB00054
# Se generó el código de barras en el archivo: LBB00055
# Se generó el código de barras en el archivo: LBB00056
# Se generó el código de barras en el archivo: LBB00057
# Se generó el código de barras en el archivo: LBB00058
# Se generó el código de barras en el archivo: LBB00059
# Se generó el código de barras en el archivo: LBB00060
# Se generó el código de barras en el archivo: LBB00061
# Se generó el código de barras en el archivo: LBB00062
# Se generó el código de barras en el archivo: LBB00063
# Se generó el código de barras en el archivo: LBB00064
# Se generó el código de barras en el archivo: LBB00065
# Se generó el código de barras en el archivo: LBB00066
# Se generó el código de barras en el archivo: LBB00067
# Se generó el código de barras en el archivo: LBB00068
# Se generó el código de barras en el archivo: LBB00069
# Se generó el código de barras en el archivo: LBB00070
# Se generó el código de barras en el archivo: LBB00071
# Se generó el código de barras en el archivo: LBB00072
# Se generó el código de barras en el archivo: LBB00073
# Se generó el código de barras en el archivo: LBB00074
# Se generó el código de barras en el archivo: LBB00075
# Se generó el código de barras en el archivo: LBB00076
# Se generó el código de barras en el archivo: LBB00077
# Se generó el código de barras en el archivo: LBB00078
# Se generó el código de barras en el archivo: LBB00079
# Se generó el código de barras en el archivo: LBB00080
# Se generó el código de barras en el archivo: LBB00081
# Se generó el código de barras en el archivo: LBB00082
# Se generó el código de barras en el archivo: LBB00083
# Se generó el código de barras en el archivo: LBB00084
# Se generó el código de barras en el archivo: LBB00085
# Se generó el código de barras en el archivo: LBB00086
# Se generó el código de barras en el archivo: LBB00087
# Se generó el código de barras en el archivo: LBB00088
# Se generó el código de barras en el archivo: LBB00089
# Se generó el código de barras en el archivo: LBB00090
# Se generó el código de barras en el archivo: LBB00091
# Se generó el código de barras en el archivo: LBB00092
# Se generó el código de barras en el archivo: LBB00093
# Se generó el código de barras en el archivo: LBB00094
# Se generó el código de barras en el archivo: LBB00095
# Se generó el código de barras en el archivo: LBB00096
# Se generó el código de barras en el archivo: LBB00097
# Se generó el código de barras en el archivo: LBB00098
# Se generó el código de barras en el archivo: LBB00099
# Se generó el código de barras en el archivo: LBB00100
# Se generó el código de barras en el archivo: LBB00101
# Se generó el código de barras en el archivo: LBB00102
# Se generó el código de barras en el archivo: LBB00103
# Se generó el código de barras en el archivo: LBB00104
# Se generó el código de barras en el archivo: LBB00105
# Se generó el código de barras en el archivo: LBB00106
# Se generó el código de barras en el archivo: LBB00107
# Se generó el código de barras en el archivo: LBB00108
